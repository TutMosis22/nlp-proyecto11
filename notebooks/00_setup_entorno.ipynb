# %% [markdown]
# # Objetivo: Instalar y verificar librerías base en entorno local o el Google Colab

# %%
# !pip install transformers diffusers evaluate datasets sentencepiece
# Out:
# ...
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# ...
#    ---------------------------------------- 0.0/3.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.6 MB 1.3 MB/s eta 0:00:03
#     --------------------------------------- 0.1/3.6 MB 787.7 kB/s eta 0:00:05
#    - -------------------------------------- 0.1/3.6 MB 901.1 kB/s eta 0:00:04
#    - -------------------------------------- 0.1/3.6 MB 853.3 kB/s eta 0:00:04
#    - -------------------------------------- 0.2/3.6 MB 807.1 kB/s eta 0:00:05
#    -- ------------------------------------- 0.2/3.6 MB 731.4 kB/s eta 0:00:05
#    -- ------------------------------------- 0.2/3.6 MB 801.7 kB/s eta 0:00:05
#    -- ------------------------------------- 0.3/3.6 MB 744.2 kB/s eta 0:00:05
#    --- ------------------------------------ 0.3/3.6 MB 707.1 kB/s eta 0:00:05
#    --- ------------------------------------ 0.3/3.6 MB 678.0 kB/s eta 0:00:05
# ...

# %% [markdown]
# # Importación básica para verificar que todo se instaló correctamente

# %%
from transformers import pipeline
from diffusers import StableDiffusionPipeline
import evaluate
import datasets

# %%
print("Entorno confiurado correctamente.")
# Out:
# Entorno confiurado correctamente.
