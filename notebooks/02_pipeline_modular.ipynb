# %% [markdown]
# Con este notebook usaremos el archivo pipeline.py y se probará cada parte del flujo: carga del modelo, generación de imagen y la visualización.

# %%
# %pip install transformers diffusers accelerate torch --quiet
# Out:
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import sys
sys.path.append("../src")
from my_pipeline import load_model, generate_image, show_image

# %%
print("Cargando el modelo...")
pipe = load_model()

print("Modelo cargado correctamente")
# Out:
# Cargando el modelo...
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
# Modelo cargado correctamente

# %%
prompts = [
    "A peruvian Andean landscape at sunset, with llamas and snowy mountains",
    "A robot writing code un a dark room, digital style",
    "A cute cartoon axolotl exploring a forest"
]

# %%
for prompt in prompts:
    print(f"Prompt: {prompt}")
    image = generate_image(pipe, prompt)
    show_image(image)
# Out:
# Prompt: A peruvian Andean landscape at sunset, with llamas and snowy mountains
#   0%|          | 0/50 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=512x512>
# Prompt: A robot writing code un a dark room, digital style
#   0%|          | 0/50 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=512x512>
# Prompt: A cute cartoon axolotl exploring a forest
#   0%|          | 0/50 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=512x512>
