# %%
# %pip install transformers diffusers accelerate torch --quiet
# Out:
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import sys
sys.path.append("../src")
from my_pipeline import load_model, generate_image, show_image, save_image
from transformers import pipeline
import torch

# %%
#CARGAMOS EL MODELO
pipe = load_model()
# Out:
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]

# %%
prompt = "A futuristic cityscape at sunset"

#GENRAMOS LA IMAGEN
image = generate_image(pipe, prompt, num_inference_steps=15, height=256, width = 256)

show_image(image)
# Out:
#   0%|          | 0/15 [00:00<?, ?it/s]

# %%
save_image(image, "../metrics/cityscapewithgpu.png")
